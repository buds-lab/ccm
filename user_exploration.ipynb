# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from utils import load_variable, user_increased_metadata

# %%
experiment_details, df_metadata = {}, {}
experiment_details['model'] = 'rdf'
experiment_details['exp_list'] = {
    'Dorn': [
        'experiments_dorn/20210407', # performance-noretrain (dist-cross) 1
        'experiments_dorn/20210411', # performance-noretrain (cross) 1
        'experiments_dorn/20210421', # SWLS
        'experiments_dorn/20210426', # agreeableness
    ], 
    'SMC': [
        'experiments_smc/20210309',  # performance-noretrain (dist-cross)
        'experiments_smc/20210304',  # performance-noretrain (cross)    
    ]
}
   
experiment_details['name_list'] = {
    'Dorn': [
        'Dist-Cross',
        'Cross',
        'Life Satisfaction',
        'Agreeableness',
    ],
    'SMC': [
        'Dist-Cross',
        'Cross',
    ]
}    
experiment_details['cluster_assign'] = {
    'Dorn': [
        'performance-noretrain',
        'performance-noretrain',
        'questions',
        'questions',
    ],
    'SMC': [
    'performance-noretrain',
    'performance-noretrain',   
    ] 
}

dict_metadata = {
    'Dorn': pd.read_csv("data/DORN_qns_all.csv"),
    'SMC': pd.read_csv("data/SMC_qns_60.csv")
    
}

# %%
user_increased_metadata(experiment_details, dict_metadata)
# Out:
# Sex breakdown for Dorn:Dist-Cross:
# Counter({'Male': 5, 'Female': 4})
# worse off people:
# Counter({'Female': 6, 'Male': 5})
# Height breakdown for Dorn:Dist-Cross:
# mean:  168.0
# std:  4.714045207910317
# worse off people:
# mean:  167.72727272727272
# std:  10.626646688147241
# Weight breakdown for {dataset}:{exp_str}:
# mean:  64.33333333333333
# std:  12.036980056845193
# worse off people:
# mean:  64.54545454545455
# std:  14.00236107599284
#
#
# Sex breakdown for Dorn:Cross:
# Counter({'Male': 6, 'Female': 6})
# worse off people:
# Counter({'Female': 4, 'Male': 4})
# Height breakdown for Dorn:Cross:
# mean:  169.08333333333334
# std:  8.948541159814202
# worse off people:
# mean:  166.0
# std:  7.3824115301167
# Weight breakdown for {dataset}:{exp_str}:
# mean:  64.08333333333333
# std:  12.990113762225315
# worse off people:
# mean:  65.0
# std:  13.379088160259652
#
#
# Sex breakdown for Dorn:Life Satisfaction:
# Counter({'Female': 3, 'Male': 1})
# worse off people:
# Counter({'Male': 3, 'Female': 3})
# Height breakdown for Dorn:Life Satisfaction:
# mean:  165.25
# std:  8.954747344286158
# worse off people:
# mean:  170.0
# std:  5.8594652770823155
# Weight breakdown for {dataset}:{exp_str}:
# mean:  55.25
# std:  5.7608593109014565
# worse off people:
# mean:  70.16666666666667
# std:  8.532617157446802
#
#
# Sex breakdown for Dorn:Agreeableness:
# Counter({'Male': 7, 'Female': 4})
# worse off people:
# Counter({'Female': 6, 'Male': 3})
# Height breakdown for Dorn:Agreeableness:
# mean:  167.1818181818182
# std:  8.695016146340611
# worse off people:
# mean:  168.66666666666666
# std:  8.16496580927726
# Weight breakdown for {dataset}:{exp_str}:
# mean:  65.81818181818181
# std:  14.326188237681635
# worse off people:
# mean:  62.77777777777778
# std:  11.340956042178158
#
#
# Sex breakdown for SMC:Dist-Cross:
# Counter({'Male': 8, 'Female': 4})
# worse off people:
# Counter({'Female': 14, 'Male': 8})
# Height breakdown for SMC:Dist-Cross:
# mean:  169.58333333333334
# std:  11.49969806366913
# worse off people:
# mean:  166.0
# std:  8.847187534619534
# Weight breakdown for {dataset}:{exp_str}:
# mean:  74.91666666666667
# std:  15.766305492691966
# worse off people:
# mean:  73.5909090909091
# std:  17.028476392926727
#
#
# Sex breakdown for SMC:Cross:
# Counter({'Male': 9, 'Female': 2})
# worse off people:
# Counter({'Female': 16, 'Male': 7})
# Height breakdown for SMC:Cross:
# mean:  174.0
# std:  7.36082999272624
# worse off people:
# mean:  164.04347826086956
# std:  9.498184086717817
# Weight breakdown for {dataset}:{exp_str}:
# mean:  78.36363636363636
# std:  18.85963813049506
# worse off people:
# mean:  72.0
# std:  14.981147573156592
